# %% [markdown]
# # Maestría en Maestría en Ciencia de Datos e Inteligencia Artificial
# #### 8. Machine Learning and Deep Learning
# #### Docente: Msc. Renzo Claure Aracena.

# %% [markdown]
# ### Regresión Logística

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap

# %%
cancer = pd.read_csv('../datasets/cancer.csv', delimiter = ";", decimal=",")

# %%
cancer.head()
# Out:
#          ID Tipo  Radio  Textura  Perimetro    Area  Suavidad  Compactavidad  \
# 0    842302    M  17.99    10.38     122.80  1001.0   0.11840        0.27760
# 1    842517    M  20.57    17.77     132.90  1326.0   0.08474        0.07864
# 2  84300903    M  19.69    21.25     130.00  1203.0   0.10960        0.15990
# 3  84348301    M  11.42    20.38      77.58   386.1   0.14250        0.28390
# 4  84358402    M  20.29    14.34     135.10  1297.0   0.10030        0.13280
#
#    Concavidad  Puntos_concavos  Simetria  Fractal
# 0      0.3001          0.14710    0.2419  0.07871
# 1      0.0869          0.07017    0.1812  0.05667
# 2      0.1974          0.12790    0.2069  0.05999
# 3      0.2414          0.10520    0.2597  0.09744
# 4      0.1980          0.10430    0.1809  0.05883

# %%
cancer.shape
# Out:
# (569, 12)

# %%
cancer['Tipo'].value_counts()
# Out:
# Tipo
# B    357
# M    212
# Name: count, dtype: int64

# %%
X_2D = cancer[['Radio', 'Simetria']]
y_2D = cancer['Tipo']

# %%
from sklearn.linear_model import LogisticRegression

# %%
#import matplotlib.pyplot as plt
#from importlib import reload
#plt=reload(plt)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_2D, y_2D, random_state=0)

plt.figure()
color = {'M' : 'red', 'B' : 'green'}
plt.scatter(X_train['Radio'].array, X_train['Simetria'].array, marker= 'o', c=y_train.map(color))
plt.title('Regresion Logistica')
plt.xlabel('Radio')
plt.ylabel('Simetria')
plt.legend(['M', 'B'])
plt.show() #fin

# %%
clasif = LogisticRegression(C=1).fit(X_train, y_train)

# %%
print('La exactitud del modelo de clasificacion de cancer sobre el entrenamiento es de:{:.2f}'.format(clasif.score(X_train, y_train)))
print('La exactitud del modelo de clasificacion de cancer sobre la comprobacion es de:{:.2f}'.format(clasif.score(X_test, y_test)))
# Out:
# La exactitud del modelo de clasificacion de cancer sobre el entrenamiento es de:0.87
# La exactitud del modelo de clasificacion de cancer sobre la comprobacion es de:0.90

# %%
Radio = 10
Simetria = 0.175

print('Un tumor con un radio  de: {} y simetria: {}, es probable que sea: {}'
      .format(Radio, Simetria, clasif.predict([[Radio, Simetria]])))
# Out:
# Un tumor con un radio  de: 10 y simetria: 0.175, es probable que sea: ['B']
# C:\Users\renzo\miniconda3\envs\base_ds_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Prueba de varios valores de C para verificar su efecto sobre la exactitud y el sobre-ajuste**

# %%
for C_i in [0.001, 0.01, 1, 10, 1000, 10000]:
    clasif = LogisticRegression(C=C_i).fit(X_train, y_train)
    score_train = clasif.score(X_train, y_train)
    score_test = clasif.score(X_test, y_test)
    print('C = {:.3f}, score entrenamiento: {:.2f}, score comprobacion: {:.2f}\n'.format(C_i, score_train, score_test))
# Out:
# C = 0.001, score entrenamiento: 0.84, score comprobacion: 0.83
#
# C = 0.010, score entrenamiento: 0.88, score comprobacion: 0.90
#
# C = 1.000, score entrenamiento: 0.87, score comprobacion: 0.90
#
# C = 10.000, score entrenamiento: 0.88, score comprobacion: 0.91
#
# C = 1000.000, score entrenamiento: 0.90, score comprobacion: 0.87
#
# C = 10000.000, score entrenamiento: 0.90, score comprobacion: 0.87

# %%
#pip install graphviz

# %% [markdown]
# **Visualización de espacios de clasificación**

# %%
from adspy_shared_utilities import plot_class_regions_for_classifier_subplot

# %%
X_2D = cancer[['Radio', 'Simetria']]
y_2D = cancer[['Tipo']].replace({'Tipo':{'B':0, 'M':1}})
y_2D = y_2D['Tipo']
# Out:
# C:\Users\renzo\AppData\Local\Temp\ipykernel_29392\3356113428.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_2D = cancer[['Tipo']].replace({'Tipo':{'B':0, 'M':1}})

# %%
X_2D = X_2D.to_numpy()
y_2D = y_2D.to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X_2D, y_2D, random_state=0)
clasif = LogisticRegression().fit(X_train, y_train)

fig, subaxes = plt.subplots(1, 1, figsize=(7, 5))
titulo = 'Regresion Logistica para Cancer, 2 variables C = {:.3f}'.format(1.0)
plot_class_regions_for_classifier_subplot(clasif, X_train[:100,:], y_train[0:100], X_test[:30,:], y_test[0:30], titulo, subaxes)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_2D, y_2D, random_state=0)

fig, subaxes = plt.subplots(3, 1, figsize=(7,10))

for C_i, subplot in zip([0.01, 1, 100], subaxes):
    clasif = LogisticRegression(C=C_i).fit(X_train, y_train)
    titulo ='Regresion Logistica Cancer C = {:.3f}'.format(C_i)
    
    plot_class_regions_for_classifier_subplot(clasif, X_train[:100,:], y_train[0:100],
                                             X_test[:30,:], y_test[0:30], titulo,
                                             subplot)
plt.tight_layout()

# %% [markdown]
# *Pruebe el Clasificador con todas las variables para C=0.01, C=1 y C=100*

# %%
X = cancer.drop(['ID', 'Tipo'], axis=1)

# %%
y = cancer['Tipo']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
mode_full = LogisticRegression().fit(X_train, y_train)

# %%
mode_full.score(X_train, y_train)

# %%
mode_full.score(X_test, y_test)
